# %%
import pandas as pd

# %%
df=pd.read_csv("tmdb_5000_movies.csv")

# %%
df.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
# ...

# %%
df["genres"].loc[0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %% [markdown]
# #### here we counting the number of rows in df[generes]

# %%
df["genres"].count()
# Out:
# 4803

# %% [markdown]
# # here we converted the string into the list form

# %%
import ast
def fun(x):
  x=ast.literal_eval(x)
  return x
for j in range(0,df["genres"].count()):
    df["genres"][j]=fun(df["genres"][j])
# Out:
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df["genres"][2]
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 80, 'name': 'Crime'}]

# %% [markdown]
# # here combined list of genres

# %%
def fun(x):
  L=[]
  for i in range(len(x)):
        L.append(x[i]["name"])
  return L
for j in range(0,df["genres"].count()):
    df["genres"][j]=fun(df["genres"][j])
# Out:
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
df["genres"][0]
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Science Fiction']

# %% [markdown]
# # here we removed spaces from strings in list

# %%
def fun(x):
    for i in range(len(x)):
        L=[]
        L=x[i].split(" ")
        x[i]="".join(L)

for j in range(0,df["genres"].count()):
   fun(df["genres"][j])

# %%
df["genres"][0]
# Out:
# ['Action', 'Adventure', 'Fantasy', 'ScienceFiction']

# %% [markdown]
# # here list is converted again into a string

# %%
def fun(x):
    s=" ".join(x)
    return s
for j in range(0,df["genres"].count()):
    df["genres"][j]=fun(df["genres"][j])
# Out:
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df["genres"][0]
# Out:
# 'Action Adventure Fantasy ScienceFiction'

# %%
df.head(2)
# Out:
#       budget                                   genres  \
# 0  237000000  Action Adventure Fantasy ScienceFiction
# 1  300000000                 Adventure Fantasy Action
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies  \
# ...

# %% [markdown]
# # Genres solved

# %% [markdown]
# # string_to_List

# %%
import ast
def fun(x):
    return ast.literal_eval(x)
    
df["keywords"]=df["keywords"].apply(fun)

# %%
df["keywords"][1]
# Out:
# [{'id': 270, 'name': 'ocean'},
#  {'id': 726, 'name': 'drug abuse'},
#  {'id': 911, 'name': 'exotic island'},
#  {'id': 1319, 'name': 'east india trading company'},
#  {'id': 2038, 'name': "love of one's life"},
#  {'id': 2052, 'name': 'traitor'},
#  {'id': 2580, 'name': 'shipwreck'},
#  {'id': 2660, 'name': 'strong woman'},
#  {'id': 3799, 'name': 'ship'},
#  {'id': 5740, 'name': 'alliance'},
#  {'id': 5941, 'name': 'calypso'},
#  {'id': 6155, 'name': 'afterlife'},
#  {'id': 6211, 'name': 'fighter'},
#  {'id': 12988, 'name': 'pirate'},
#  {'id': 157186, 'name': 'swashbuckler'},
#  {'id': 179430, 'name': 'aftercreditsstinger'}]

# %%
def fun(x):
    L=[]
    for i in x:
        L.append(i["name"])
    return L
df["keywords"]=df["keywords"].apply(fun)

# %%
df["keywords"][0]
# Out:
# ['culture clash',
#  'future',
#  'space war',
#  'space colony',
#  'society',
#  'space travel',
#  'futuristic',
#  'romance',
#  'space',
#  'alien',
#  'tribe',
#  'alien planet',
#  'cgi',
#  'marine',
#  'soldier',
#  'battle',
#  'love affair',
#  'anti war',
#  'power relations',
#  'mind and soul',
#  '3d']

# %%
def fun(x):
    L2=[]
    L=[]
    for i in x:
        L=i.split(" ")
        s="".join(L)
        L2.append(s)
    return L2
df["keywords"]=df["keywords"].apply(fun)

# %%
df["keywords"][0]
# Out:
# ['cultureclash',
#  'future',
#  'spacewar',
#  'spacecolony',
#  'society',
#  'spacetravel',
#  'futuristic',
#  'romance',
#  'space',
#  'alien',
#  'tribe',
#  'alienplanet',
#  'cgi',
#  'marine',
#  'soldier',
#  'battle',
#  'loveaffair',
#  'antiwar',
#  'powerrelations',
#  'mindandsoul',
#  '3d']

# %%
def fun(x):
    x=" ".join(x)
    return x
df["keywords"]=df["keywords"].apply(fun)

# %%
df["keywords"][0]
# Out:
# 'cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d'

# %% [markdown]
# # keywords_arranged

# %%
df.head(2)
# Out:
#       budget                                   genres  \
# 0  237000000  Action Adventure Fantasy ScienceFiction
# 1  300000000                 Adventure Fantasy Action
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  cultureclash future spacewar spacecolony socie...                en
# 1  ocean drugabuse exoticisland eastindiatradingc...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies  \
# ...

# %% [markdown]
# # these are hindi movies

# %%
for i in range(len(df["original_language"])):
    if(df["original_language"][i]=='hi'):
        print(df.loc[i,"title"])
# Out:
# Earth
# Kabhi Alvida Naa Kehna
# Housefull
# Krrish
# Jab Tak Hai Jaan
# Yeh Jawaani Hai Deewani
# Ta Ra Rum Pum
# Veer-Zaara
# Rang De Basanti
# Dum Maaro Dum
# Gandhi, My Father
# Airlift
# ABCD (Any Body Can Dance)
# The Lunchbox
# Dil Jo Bhi Kahey...
# Monsoon Wedding
# Rocket Singh: Salesman of the Year
# Fiza
# Faith Connections

# %%
df2=pd.read_csv("tmdb_5000_credits.csv")

# %%
df2.head(3)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...

# %%
df=df.merge(df2)

# %%
df
# Out:
#          budget                                   genres  \
# 0     237000000  Action Adventure Fantasy ScienceFiction
# 1     300000000                 Adventure Fantasy Action
# 2     245000000                   Action Adventure Crime
# 3     250000000              Action Crime Drama Thriller
# 4     260000000          Action Adventure ScienceFiction
# ...         ...                                      ...
# 4804     220000                    Action Crime Thriller
# 4805       9000                           Comedy Romance
# 4806          0             Comedy Drama Romance TVMovie
# 4807          0
# 4808          0                              Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# ...

# %% [markdown]
# # cast started

# %%
def fun(x):
    return ast.literal_eval(x)
df["cast"]=df["cast"].apply(fun)

# %%
df["cast"][0]
# Out:
# [{'cast_id': 242,
#   'character': 'Jake Sully',
#   'credit_id': '5602a8a7c3a3685532001c9a',
#   'gender': 2,
#   'id': 65731,
#   'name': 'Sam Worthington',
#   'order': 0},
#  {'cast_id': 3,
#   'character': 'Neytiri',
#   'credit_id': '52fe48009251416c750ac9cb',
#   'gender': 1,
#   'id': 8691,
#   'name': 'Zoe Saldana',
#   'order': 1},
#  {'cast_id': 25,
#   'character': 'Dr. Grace Augustine',
#   'credit_id': '52fe48009251416c750aca39',
#   'gender': 1,
#   'id': 10205,
#   'name': 'Sigourney Weaver',
#   'order': 2},
#  {'cast_id': 4,
#   'character': 'Col. Quaritch',
#   'credit_id': '52fe48009251416c750ac9cf',
#   'gender': 2,
#   'id': 32747,
#   'name': 'Stephen Lang',
#   'order': 3},
#  {'cast_id': 5,
#   'character': 'Trudy Chacon',
#   'credit_id': '52fe48009251416c750ac9d3',
#   'gender': 1,
#   'id': 17647,
#   'name': 'Michelle Rodriguez',
#   'order': 4},
#  {'cast_id': 8,
#   'character': 'Selfridge',
#   'credit_id': '52fe48009251416c750ac9e1',
#   'gender': 2,
# ...

# %%
def fun(x):
    L=[]
    for i in x:
        L.append(i["name"])
    return L
df["cast"]=df["cast"].apply(fun)

# %%
df.cast[0]
# Out:
# ['Sam Worthington',
#  'Zoe Saldana',
#  'Sigourney Weaver',
#  'Stephen Lang',
#  'Michelle Rodriguez',
#  'Giovanni Ribisi',
#  'Joel David Moore',
#  'CCH Pounder',
#  'Wes Studi',
#  'Laz Alonso',
#  'Dileep Rao',
#  'Matt Gerald',
#  'Sean Anthony Moran',
#  'Jason Whyte',
#  'Scott Lawrence',
#  'Kelly Kilgour',
#  'James Patrick Pitt',
#  'Sean Patrick Murphy',
#  'Peter Dillon',
#  'Kevin Dorman',
#  'Kelson Henderson',
#  'David Van Horn',
#  'Jacob Tomuri',
#  'Michael Blain-Rozgay',
#  'Jon Curry',
#  'Luke Hawker',
#  'Woody Schultz',
#  'Peter Mensah',
#  'Sonia Yee',
#  'Jahnel Curfman',
#  'Ilram Choi',
#  'Kyla Warren',
#  'Lisa Roumain',
#  'Debra Wilson',
#  'Chris Mala',
#  'Taylor Kibby',
#  'Jodie Landau',
#  'Julie Lamm',
#  'Cullen B. Madden',
#  'Joseph Brady Madden',
#  'Frankie Torres',
#  'Austin Wilson',
#  'Sara Wilson',
#  'Tamica Washington-Miller',
#  'Lucy Briant',
#  'Nathan Meister',
#  'Gerry Blair',
#  'Matthew Chamberlain',
#  'Paul Yates',
# ...

# %%
for i in range(len(df["cast"])):
    df["cast"][i]=df["cast"][i][0:3]
# Out:
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for i in range(len(df["cast"])):
    L=[]
    L1=[]
    for j in df["cast"][i]:
        L=j.split(" ")
        s="".join(L)
        L1.append(s)
    df["cast"][i]=L1
# Out:
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.cast[0]
# Out:
# ['SamWorthington', 'ZoeSaldana', 'SigourneyWeaver']

# %%
for i in range(len(df.cast)):
    df["cast"][i]=" ".join(df["cast"][i])
# Out:
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df["cast"][0]
# Out:
# 'SamWorthington ZoeSaldana SigourneyWeaver'

# %%
df=df[["id","genres","title","overview","cast","crew","keywords"]]

# %%
df.head(2)
# Out:
#       id                                   genres  \
# 0  19995  Action Adventure Fantasy ScienceFiction
# 1    285                 Adventure Fantasy Action
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
#
#                                         cast  \
# 0  SamWorthington ZoeSaldana SigourneyWeaver
# 1     JohnnyDepp OrlandoBloom KeiraKnightley
#
#                                                 crew  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
#
#                                             keywords
# 0  cultureclash future spacewar spacecolony socie...
# 1  ocean drugabuse exoticisland eastindiatradingc...

# %% [markdown]
# # castis completed

# %% [markdown]
# # crew is started

# %%
def fun(x):
    return ast.literal_eval(x)
df["crew"]=df["crew"].apply(fun)
# Out:
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.crew[6]
# Out:
# [{'credit_id': '52fe46db9251416c91062101',
#   'department': 'Production',
#   'gender': 2,
#   'id': 7879,
#   'job': 'Executive Producer',
#   'name': 'John Lasseter'},
#  {'credit_id': '52fe46db9251416c910620e3',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 38748,
#   'job': 'Novel',
#   'name': 'Jacob Grimm'},
#  {'credit_id': '52fe46db9251416c910620dd',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 5448,
#   'job': 'Novel',
#   'name': 'Wilhelm Grimm'},
#  {'credit_id': '572bc6f992514138820000d3',
#   'department': 'Visual Effects',
#   'gender': 0,
#   'id': 8020,
#   'job': 'Animation Supervisor',
#   'name': 'John Kahrs'},
#  {'credit_id': '572bc5d3c3a3687ffd0000a3',
#   'department': 'Art',
#   'gender': 0,
#   'id': 12072,
#   'job': 'Production Design',
#   'name': 'Douglas Rogers'},
#  {'credit_id': '52fe46db9251416c910620e9',
#   'department': 'Sound',
#   'gender': 2,
#   'id': 15813,
#   'job': 'Original Music Composer',
# ...

# %%
print(df["crew"].count())

for i in range(len(df["crew"])):
   for j in range(len(df["crew"][i])):
      if df["crew"][i][j]["job"]=="Director":
                   df["crew"][i]=df["crew"][i][j]["name"]
                   break;
# Out:
# 4809
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def fun(x):
    if type(x)==list:
        s="and"
        return s
    else:
        return x
df["crew"]=df["crew"].apply(fun)
# Out:
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df["crew"][3736]
# Out:
# 'and'

# %%
def fun(x):
    L=[]
    L=x.split(" ")
    s="".join(L)
    return s
for i in range(len(df["crew"])):
   df["crew"][i]=fun(df["crew"][i])
# Out:
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
j=0
for i in df["crew"]:
    print(i,j)
    j+=1
# Out:
# JamesCameron 0
# GoreVerbinski 1
# SamMendes 2
# ChristopherNolan 3
# AndrewStanton 4
# SamRaimi 5
# ByronHoward 6
# JossWhedon 7
# DavidYates 8
# ZackSnyder 9
# BryanSinger 10
# MarcForster 11
# GoreVerbinski 12
# GoreVerbinski 13
# ZackSnyder 14
# AndrewAdamson 15
# JossWhedon 16
# RobMarshall 17
# BarrySonnenfeld 18
# PeterJackson 19
# MarcWebb 20
# RidleyScott 21
# PeterJackson 22
# ChrisWeitz 23
# PeterJackson 24
# JamesCameron 25
# AnthonyRusso 26
# PeterBerg 27
# ColinTrevorrow 28
# SamMendes 29
# SamRaimi 30
# ShaneBlack 31
# TimBurton 32
# BrettRatner 33
# DanScanlon 34
# MichaelBay 35
# MichaelBay 36
# SamRaimi 37
# MarcWebb 38
# JosephKosinski 39
# JohnLasseter 40
# MartinCampbell 41
# LeeUnkrich 42
# McG 43
# JamesWan 44
# MarcForster 45
# BryanSinger 46
# J.J.Abrams 47
# BryanSinger 48
# BazLuhrmann 49
# MikeNewell 50
# GuillermodelToro 51
# MichaelBay 52
# StevenSpielberg 53
# PeterSohn 54
# BrendaChapman 55
# JustinLin 56
# AndrewStanton 57
# BrettRatner 58
# ...

# %%
df["crew"][3736]
# Out:
# 'and'

# %%
df.crew[3669]
# Out:
# 'And'

# %%
j=0
for i in df["crew"]:
    print(i,j)
    j+=1
# Out:
# JamesCameron 0
# GoreVerbinski 1
# SamMendes 2
# ChristopherNolan 3
# AndrewStanton 4
# SamRaimi 5
# ByronHoward 6
# JossWhedon 7
# DavidYates 8
# ZackSnyder 9
# BryanSinger 10
# MarcForster 11
# GoreVerbinski 12
# GoreVerbinski 13
# ZackSnyder 14
# AndrewAdamson 15
# JossWhedon 16
# RobMarshall 17
# BarrySonnenfeld 18
# PeterJackson 19
# MarcWebb 20
# RidleyScott 21
# PeterJackson 22
# ChrisWeitz 23
# PeterJackson 24
# JamesCameron 25
# AnthonyRusso 26
# PeterBerg 27
# ColinTrevorrow 28
# SamMendes 29
# SamRaimi 30
# ShaneBlack 31
# TimBurton 32
# BrettRatner 33
# DanScanlon 34
# MichaelBay 35
# MichaelBay 36
# SamRaimi 37
# MarcWebb 38
# JosephKosinski 39
# JohnLasseter 40
# MartinCampbell 41
# LeeUnkrich 42
# McG 43
# JamesWan 44
# MarcForster 45
# BryanSinger 46
# J.J.Abrams 47
# BryanSinger 48
# BazLuhrmann 49
# MikeNewell 50
# GuillermodelToro 51
# MichaelBay 52
# StevenSpielberg 53
# PeterSohn 54
# BrendaChapman 55
# JustinLin 56
# AndrewStanton 57
# BrettRatner 58
# ...

# %%
df.isnull().sum()
# Out:
# id          0
# genres      0
# title       0
# overview    3
# cast        0
# crew        0
# keywords    0
# dtype: int64

# %% [markdown]
# # crew is completed

# %%
df.head()
# Out:
#        id                                   genres  \
# 0   19995  Action Adventure Fantasy ScienceFiction
# 1     285                 Adventure Fantasy Action
# 2  206647                   Action Adventure Crime
# 3   49026              Action Crime Drama Thriller
# 4   49529          Action Adventure ScienceFiction
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
# ...

# %%
df.dropna(inplace=True)
# Out:
# /home/nitish/snap/jupyter/common/lib/python3.7/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df.isnull().sum()
# Out:
# id          0
# genres      0
# title       0
# overview    0
# cast        0
# crew        0
# keywords    0
# dtype: int64

# %%
df1=pd.DataFrame(df["id"])

# %%
df1.head()
# Out:
#        id
# 0   19995
# 1     285
# 2  206647
# 3   49026
# 4   49529

# %%
df1["tag"]=df["overview"]+df["genres"]+df["cast"]+df["crew"]+df["keywords"]

# %%
df1.head()
# Out:
#        id                                                tag
# 0   19995  In the 22nd century, a paraplegic Marine is di...
# 1     285  Captain Barbossa, long believed to be dead, ha...
# 2  206647  A cryptic message from Bond’s past sends him o...
# 3   49026  Following the death of District Attorney Harve...
# 4   49529  John Carter is a war-weary, former military ca...

# %%
del df1["keywords"]

# %%
df1
# Out:
#           id                                                tag
# 0      19995  In the 22nd century, a paraplegic Marine is di...
# 1        285  Captain Barbossa, long believed to be dead, ha...
# 2     206647  A cryptic message from Bond’s past sends him o...
# 3      49026  Following the death of District Attorney Harve...
# 4      49529  John Carter is a war-weary, former military ca...
# ...      ...                                                ...
# 4804    9367  El Mariachi just wants to play his guitar and ...
# 4805   72766  A newlywed couple's honeymoon is upended by th...
# 4806  231617  "Signed, Sealed, Delivered" introduces a dedic...
# 4807  126186  When ambitious New York attorney Sam is sent t...
# 4808   25975  Ever since the second grade when he first saw ...
#
# [4806 rows x 2 columns]

# %%
import openpyxl as xls

# %%
# Arranged_dataset2=pd.ExcelWriter("Arranged_Dataset2.xlsx")

# %%
# df1.to_csv("Arranged_dataset2.csv")

# %%
# Arranged_dataset2.save()

# %%
# df.to_csv("Arranged_dataset1.csv")

# %%
df
# Out:
#           id                                   genres  \
# 0      19995  Action Adventure Fantasy ScienceFiction
# 1        285                 Adventure Fantasy Action
# 2     206647                   Action Adventure Crime
# 3      49026              Action Crime Drama Thriller
# 4      49529          Action Adventure ScienceFiction
# ...      ...                                      ...
# 4804    9367                    Action Crime Thriller
# 4805   72766                           Comedy Romance
# 4806  231617             Comedy Drama Romance TVMovie
# 4807  126186
# 4808   25975                              Documentary
#
#                                          title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# ...

# %%
df1=df1.merge(df)

# %%
del df1["crew"]
del df1["cast"]
del df1["keywords"]
del df1["overview"]
del df1["genres"]

# %%
df1
# Out:
#           id                                                tag  \
# 0      19995  In the 22nd century, a paraplegic Marine is di...
# 1        285  Captain Barbossa, long believed to be dead, ha...
# 2     206647  A cryptic message from Bond’s past sends him o...
# 3      49026  Following the death of District Attorney Harve...
# 4      49529  John Carter is a war-weary, former military ca...
# ...      ...                                                ...
# 4813    9367  El Mariachi just wants to play his guitar and ...
# 4814   72766  A newlywed couple's honeymoon is upended by th...
# 4815  231617  "Signed, Sealed, Delivered" introduces a dedic...
# 4816  126186  When ambitious New York attorney Sam is sent t...
# 4817   25975  Ever since the second grade when he first saw ...
#
#                                          title
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# ...

# %%
df1.to_csv("Final_arranged.csv")
